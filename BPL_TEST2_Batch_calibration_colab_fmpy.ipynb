# %% [markdown]
# <a href="https://colab.research.google.com/github/janpeter19/BPL_TEST2_Batch_calibration/blob/main/BPL_TEST2_Batch_calibration_colab_fmpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BPL_TEST2_Batch_calibration script with FMPy ver 0.3.15
#
# The key library FMPy ver 0.3.15 and scipy and more are installed.
#
# After the installation a small application BPL_TEST2_Batch_calibration is loaded and run. You can continue with this example if you like.

# %%
# !lsb_release -a # Actual VM Ubuntu version used by Google
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 20.04.5 LTS
# Release:	20.04
# Codename:	focal

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_22.11.1-1-Linux-x86_64.sh 
# !chmod +x Miniconda3-py38_22.11.1-1-Linux-x86_64.sh
# !bash ./Miniconda3-py38_22.11.1-1-Linux-x86_64.sh -b -f -p /usr/local 
import sys 
sys.path.append('/usr/local/lib/python3.8/site-packages/')
# Out:
# --2023-03-09 10:56:10--  https://repo.anaconda.com/miniconda/Miniconda3-py38_22.11.1-1-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64630241 (62M) [application/x-sh]
# Saving to: ‘Miniconda3-py38_22.11.1-1-Linux-x86_64.sh’
#
# Miniconda3-py38_22. 100%[===================>]  61.64M  31.2MB/s    in 2.0s
#
# 2023-03-09 10:56:13 (31.2 MB/s) - ‘Miniconda3-py38_22.11.1-1-Linux-x86_64.sh’ saved [64630241/64630241]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# Downloading and Extracting Packages
#
#
# Downloading and Extracting Packages
#
# done
# done
# installation finished.

# %%
# !conda update -n base -c defaults conda --yes
# Out:
# done
# |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::pyqtwebengine==5.15.7=py38h6a678d5_1
#   - defaults/linux-64::libtiff==4.5.0=h6a678d5_2
#   - defaults/linux-64::pillow==9.4.0=py38h6a678d5_0
#   - conda-forge/noarch::fmpy==0.3.15=h13ae965_0
#   - defaults/linux-64::matplotlib-base==3.7.0=py38h417a72b_0
#   - defaults/linux-64::pyqt==5.15.7=py38h6a678d5_1
#   - conda-forge/noarch::bokeh==2.4.3=pyhd8ed1ab_3
#   - defaults/linux-64::matplotlib==3.7.0=py38h06a4308_0
#   - conda-forge/noarch::dask==2023.3.0=pyhd8ed1ab_0
#   - defaults/linux-64::lcms2==2.12=h3be6417_0
#   - defaults/linux-64::libwebp==1.2.4=h11a3e52_1
#   - defaults/linux-64::qtwebkit==5.212=h4eab89a_4
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     attrs-22.1.0               |   py38h06a4308_0          85 KB
#     brotli-python-1.0.9        |   py38h6a678d5_7         329 KB
#     click-8.0.4                |   py38h06a4308_0         151 KB
#     cloudpickle-2.0.0          |     pyhd3eb1b0_0          32 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     dash-2.7.0                 |   py38h06a4308_0         6.4 MB
#     expat-2.4.9                |       h6a678d5_0         156 KB
#     flask-2.2.2                |   py38h06a4308_0         147 KB
#     flask-compress-1.13        |   py38h06a4308_0          19 KB
#     flit-core-3.6.0            |     pyhd3eb1b0_0          42 KB
#     fontconfig-2.14.1          |       h52c9d5c_1         281 KB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     fsspec-2022.11.0           |   py38h06a4308_0         223 KB
#     giflib-5.2.1               |       h5eee18b_3          80 KB
#     heapdict-1.0.1             |     pyhd3eb1b0_0           8 KB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     importlib-metadata-4.11.3  |   py38h06a4308_0          40 KB
#     importlib_resources-5.2.0  |     pyhd3eb1b0_1          21 KB
#     itsdangerous-2.0.1         |     pyhd3eb1b0_0          18 KB
#     jinja2-3.1.2               |   py38h06a4308_0         211 KB
#     jpeg-9e                    |       h5eee18b_1         262 KB
#     jsonschema-4.17.3          |   py38h06a4308_0         140 KB
#     jupyter_core-5.2.0         |   py38h06a4308_0          89 KB
#     krb5-1.19.4                |       h568e23c_0         1.3 MB
#     libedit-3.1.20221030       |       h5eee18b_0         181 KB
#     libllvm10-10.0.1           |       hbcb73fb_5        22.1 MB
#     libuuid-1.41.5             |       h5eee18b_0          27 KB
#     locket-1.0.0               |   py38h06a4308_0          11 KB
#     lz4-c-1.9.4                |       h6a678d5_0         154 KB
#     mkl-service-2.4.0          |   py38h7f8727e_0          59 KB
#     mkl_fft-1.3.1              |   py38hd3c417c_0         180 KB
#     mkl_random-1.2.2           |   py38h51133e4_0         308 KB
#     nbformat-5.7.0             |   py38h06a4308_0         133 KB
#     packaging-22.0             |   py38h06a4308_0          68 KB
#     partd-1.2.0                |     pyhd3eb1b0_1          18 KB
#     pathlib-1.0.1              |     pyhd3eb1b0_1          17 KB
#     pcre-8.45                  |       h295c915_0         207 KB
#     pkgutil-resolve-name-1.3.10|   py38h06a4308_0           9 KB
#     platformdirs-2.5.2         |   py38h06a4308_0          23 KB
#     plotly-5.9.0               |   py38h06a4308_0         4.0 MB
#     ply-3.11                   |           py38_0          81 KB
#     pyparsing-3.0.9            |   py38h06a4308_0         152 KB
#     pyqtgraph-0.13.1           |   py38h06a4308_0         1.2 MB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     python-fastjsonschema-2.16.2|   py38h06a4308_0         230 KB
#     pytz-2022.7                |   py38h06a4308_0         209 KB
#     pyyaml-6.0                 |   py38h5eee18b_1         189 KB
#     sortedcontainers-2.4.0     |     pyhd3eb1b0_0          26 KB
#     tblib-1.7.0                |     pyhd3eb1b0_0          15 KB
#     tenacity-8.0.1             |   py38h06a4308_1          34 KB
#     toml-0.10.2                |     pyhd3eb1b0_0          20 KB
#     tornado-6.2                |   py38h5eee18b_0         590 KB
#     traitlets-5.7.1            |   py38h06a4308_0         200 KB
#     typing_extensions-4.4.0    |   py38h06a4308_0          46 KB
#     werkzeug-2.2.2             |   py38h06a4308_0         339 KB
#     yaml-0.2.5                 |       h7b6447c_0          75 KB
#     zict-2.1.0                 |   py38h06a4308_0          20 KB
#     zipp-3.11.0                |   py38h06a4308_0          19 KB
#     ------------------------------------------------------------
#                                            Total:        52.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   flit-core          pkgs/main/noarch::flit-core-3.6.0-pyhd3eb1b0_0
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.10.11-h06a4308_0 --> 2023.01.10-h06a4308_0
#   conda                              22.11.1-py38h06a4308_4 --> 23.1.0-py38h06a4308_0
#   conda-package-han~                   1.9.0-py38h5eee18b_1 --> 2.0.2-py38h06a4308_0
#   cryptography                        38.0.1-py38h9ce1e76_0 --> 39.0.1-py38h9ce1e76_0
#   expat                conda-forge::expat-2.2.10-h9c3ff4c_0 --> pkgs/main::expat-2.4.9-h6a678d5_0
#   fontconfig                              2.14.1-hef1e5e3_0 --> 2.14.1-h52c9d5c_1
#   freetype           conda-forge::freetype-2.10.4-h0708190~ --> pkgs/main::freetype-2.12.1-h4a9f257_0
#   giflib               conda-forge::giflib-5.2.1-h36c2ea0_2 --> pkgs/main::giflib-5.2.1-h5eee18b_3
#   krb5                  conda-forge::krb5-1.19.3-h3790be6_0 --> pkgs/main::krb5-1.19.4-h568e23c_0
#   libedit            conda-forge::libedit-3.1.20191231-he2~ --> pkgs/main::libedit-3.1.20221030-h5eee18b_0
#   libllvm10          conda-forge::libllvm10-10.0.1-he513fc~ --> pkgs/main::libllvm10-10.0.1-hbcb73fb_5
#   lz4-c                 conda-forge::lz4-c-1.9.3-h9c3ff4c_1 --> pkgs/main::lz4-c-1.9.4-h6a678d5_0
#   ncurses                                    6.3-h5eee18b_3 --> 6.4-h6a678d5_0
#   openssl                                 1.1.1s-h7f8727e_0 --> 1.1.1t-h7f8727e_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-py~ --> pkgs/main/linux-64::pyopenssl-23.0.0-py38h06a4308_0
#   sqlite                                  3.40.0-h5082296_0 --> 3.40.1-h5082296_0
#   tornado            conda-forge::tornado-6.1-py38h0a891b7~ --> pkgs/main::tornado-6.2-py38h5eee18b_0
#   urllib3                            1.26.13-py38h06a4308_0 --> 1.26.14-py38h06a4308_0
#   xz                                       5.2.8-h5eee18b_0 --> 5.2.10-h5eee18b_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   attrs              conda-forge/noarch::attrs-22.2.0-pyh7~ --> pkgs/main/linux-64::attrs-22.1.0-py38h06a4308_0
#   brotli-python      conda-forge::brotli-python-1.0.9-py38~ --> pkgs/main::brotli-python-1.0.9-py38h6a678d5_7
#   click              conda-forge/noarch::click-8.1.3-unix_~ --> pkgs/main/linux-64::click-8.0.4-py38h06a4308_0
#   cloudpickle        conda-forge::cloudpickle-2.2.1-pyhd8e~ --> pkgs/main::cloudpickle-2.0.0-pyhd3eb1b0_0
#   cycler             conda-forge::cycler-0.11.0-pyhd8ed1ab~ --> pkgs/main::cycler-0.11.0-pyhd3eb1b0_0
#   dash               conda-forge/noarch::dash-2.8.1-pyhd8e~ --> pkgs/main/linux-64::dash-2.7.0-py38h06a4308_0
#   flask              conda-forge/noarch::flask-2.2.3-pyhd8~ --> pkgs/main/linux-64::flask-2.2.2-py38h06a4308_0
#   flask-compress     conda-forge/noarch::flask-compress-1.~ --> pkgs/main/linux-64::flask-compress-1.13-py38h06a4308_0
#   fsspec             conda-forge/noarch::fsspec-2023.3.0-p~ --> pkgs/main/linux-64::fsspec-2022.11.0-py38h06a4308_0
#   heapdict                 conda-forge::heapdict-1.0.1-py_0 --> pkgs/main::heapdict-1.0.1-pyhd3eb1b0_0
#   icu                   conda-forge::icu-58.2-hf484d3e_1000 --> pkgs/main::icu-58.2-he6710b0_3
#   importlib-metadata conda-forge/noarch::importlib-metadat~ --> pkgs/main/linux-64::importlib-metadata-4.11.3-py38h06a4308_0
#   importlib_resourc~ conda-forge::importlib_resources-5.12~ --> pkgs/main::importlib_resources-5.2.0-pyhd3eb1b0_1
#   itsdangerous       conda-forge::itsdangerous-2.1.2-pyhd8~ --> pkgs/main::itsdangerous-2.0.1-pyhd3eb1b0_0
#   jinja2             conda-forge/noarch::jinja2-3.1.2-pyhd~ --> pkgs/main/linux-64::jinja2-3.1.2-py38h06a4308_0
#   jpeg                      conda-forge::jpeg-9e-h166bdaf_1 --> pkgs/main::jpeg-9e-h5eee18b_1
#   jsonschema         conda-forge/noarch::jsonschema-4.17.3~ --> pkgs/main/linux-64::jsonschema-4.17.3-py38h06a4308_0
#   jupyter_core       conda-forge::jupyter_core-5.2.0-py38h~ --> pkgs/main::jupyter_core-5.2.0-py38h06a4308_0
#   locket             conda-forge/noarch::locket-1.0.0-pyhd~ --> pkgs/main/linux-64::locket-1.0.0-py38h06a4308_0
#   mkl-service        conda-forge::mkl-service-2.4.0-py38h9~ --> pkgs/main::mkl-service-2.4.0-py38h7f8727e_0
#   mkl_fft            conda-forge::mkl_fft-1.3.1-py38h86662~ --> pkgs/main::mkl_fft-1.3.1-py38hd3c417c_0
#   mkl_random         conda-forge::mkl_random-1.2.2-py38h1a~ --> pkgs/main::mkl_random-1.2.2-py38h51133e4_0
#   nbformat           conda-forge/noarch::nbformat-5.7.3-py~ --> pkgs/main/linux-64::nbformat-5.7.0-py38h06a4308_0
#   packaging          conda-forge/noarch::packaging-23.0-py~ --> pkgs/main/linux-64::packaging-22.0-py38h06a4308_0
#   partd               conda-forge::partd-1.3.0-pyhd8ed1ab_0 --> pkgs/main::partd-1.2.0-pyhd3eb1b0_1
#   pathlib            conda-forge/linux-64::pathlib-1.0.1-p~ --> pkgs/main/noarch::pathlib-1.0.1-pyhd3eb1b0_1
#   pcre                    conda-forge::pcre-8.45-h9c3ff4c_0 --> pkgs/main::pcre-8.45-h295c915_0
#   pkgutil-resolve-n~ conda-forge/noarch::pkgutil-resolve-n~ --> pkgs/main/linux-64::pkgutil-resolve-name-1.3.10-py38h06a4308_0
#   platformdirs       conda-forge/noarch::platformdirs-3.1.~ --> pkgs/main/linux-64::platformdirs-2.5.2-py38h06a4308_0
#   plotly             conda-forge/noarch::plotly-5.13.1-pyh~ --> pkgs/main/linux-64::plotly-5.9.0-py38h06a4308_0
#   ply                     conda-forge/noarch::ply-3.11-py_1 --> pkgs/main/linux-64::ply-3.11-py38_0
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-p~ --> pkgs/main/linux-64::pyparsing-3.0.9-py38h06a4308_0
#   pyqtgraph          conda-forge/noarch::pyqtgraph-0.13.2-~ --> pkgs/main/linux-64::pyqtgraph-0.13.1-py38h06a4308_0
#   python-dateutil    conda-forge::python-dateutil-2.8.2-py~ --> pkgs/main::python-dateutil-2.8.2-pyhd3eb1b0_0
#   python-fastjsonsc~ conda-forge/noarch::python-fastjsonsc~ --> pkgs/main/linux-64::python-fastjsonschema-2.16.2-py38h06a4308_0
#   pytz               conda-forge/noarch::pytz-2022.7.1-pyh~ --> pkgs/main/linux-64::pytz-2022.7-py38h06a4308_0
#   pyyaml             conda-forge::pyyaml-6.0-py38h0a891b7_4 --> pkgs/main::pyyaml-6.0-py38h5eee18b_1
#   sortedcontainers   conda-forge::sortedcontainers-2.4.0-p~ --> pkgs/main::sortedcontainers-2.4.0-pyhd3eb1b0_0
#   tblib               conda-forge::tblib-1.7.0-pyhd8ed1ab_0 --> pkgs/main::tblib-1.7.0-pyhd3eb1b0_0
#   tenacity           conda-forge/noarch::tenacity-8.2.2-py~ --> pkgs/main/linux-64::tenacity-8.0.1-py38h06a4308_1
#   toml                conda-forge::toml-0.10.2-pyhd8ed1ab_0 --> pkgs/main::toml-0.10.2-pyhd3eb1b0_0
#   traitlets          conda-forge/noarch::traitlets-5.9.0-p~ --> pkgs/main/linux-64::traitlets-5.7.1-py38h06a4308_0
#   typing_extensions  conda-forge/noarch::typing_extensions~ --> pkgs/main/linux-64::typing_extensions-4.4.0-py38h06a4308_0
#   werkzeug           conda-forge/noarch::werkzeug-2.2.3-py~ --> pkgs/main/linux-64::werkzeug-2.2.2-py38h06a4308_0
#   yaml                   conda-forge::yaml-0.2.5-h7f98852_2 --> pkgs/main::yaml-0.2.5-h7b6447c_0
#   zict               conda-forge/noarch::zict-2.2.0-pyhd8e~ --> pkgs/main/linux-64::zict-2.1.0-py38h06a4308_0
#   zipp               conda-forge/noarch::zipp-3.15.0-pyhd8~ --> pkgs/main/linux-64::zipp-3.11.0-py38h06a4308_0
#
#
#
# Downloading and Extracting Packages
# locket-1.0.0         | 11 KB     | :   0% 0/1 [00:00<?, ?it/s]
# importlib-metadata-4 | 40 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
# pcre-8.45            | 207 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# fontconfig-2.14.1    | 281 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# heapdict-1.0.1       | 8 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# itsdangerous-2.0.1   | 18 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pkgutil-resolve-name | 9 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# nbformat-5.7.0       | 133 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# mkl_fft-1.3.1        | 180 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# krb5-1.19.4          | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# tenacity-8.0.1       | 34 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# sortedcontainers-2.4 | 26 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# click-8.0.4          | 151 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# zipp-3.11.0          | 19 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# flit-core-3.6.0      | 42 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 59 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libedit-3.1.20221030 | 181 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.2     | 308 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 154 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# fontconfig-2.14.1    | 281 KB    | :   6% 0.05688197614873192/1 [00:00<00:01,  1.94s/it]
#
# locket-1.0.0         | 11 KB     | : 100% 1.0/1 [00:00<00:00,  7.96it/s]
#
#
#
#
# itsdangerous-2.0.1   | 18 KB     | :  88% 0.882663506087706/1 [00:00<00:00,  7.59it/s]
#
#
#
#
#
#
# nbformat-5.7.0       | 133 KB    | :  12% 0.12000996176440427/1 [00:00<00:01,  1.23s/it]
#
#
#
#
#
# pkgutil-resolve-name | 9 KB      | : 100% 1.0/1 [00:00<00:00,  6.60it/s]
#
#
#
#
#
#
#
#
# krb5-1.19.4          | 1.3 MB    | :   1% 0.01170283206535986/1 [00:00<00:13, 13.32s/it]
#
#
#
#
#
#
#
# mkl_fft-1.3.1        | 180 KB    | :   9% 0.08868200270635995/1 [00:00<00:01,  1.76s/it]
# importlib-metadata-4 | 40 KB     | : 100% 1.0/1 [00:00<00:00,  5.20it/s]
# importlib-metadata-4 | 40 KB     | : 100% 1.0/1 [00:00<00:00,  5.20it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# zipp-3.11.0          | 19 KB     | :  84% 0.8410245880601612/1 [00:00<00:00,  4.08it/s]
#
#
#
#
#
#
#
#
#
#
#
# click-8.0.4          | 151 KB    | :  11% 0.10565414775072225/1 [00:00<00:01,  1.96s/it]
#
#
#
#
#
#
#
#
#
#
# sortedcontainers-2.4 | 26 KB     | :  62% 0.6195734382090455/1 [00:00<00:00,  2.95it/s]
#
#
#
#
#
#
#
#
#
# tenacity-8.0.1       | 34 KB     | :  47% 0.467953844396207/1 [00:00<00:00,  2.13it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# flit-core-3.6.0      | 42 KB     | :  38% 0.37697298789747363/1 [00:00<00:00,  1.52it/s]
#
#
#
#
#
#
#
#
# krb5-1.19.4          | 1.3 MB    | :  70% 0.7021699239215916/1 [00:00<00:00,  3.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libedit-3.1.20221030 | 181 KB    | :   9% 0.08829298786402535/1 [00:00<00:02,  2.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.2     | 308 KB    | :   5% 0.05193109241033931/1 [00:00<00:04,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 59 KB     | :  27% 0.2692743857342427/1 [00:00<00:00,  1.04it/s]
#
#
#
# heapdict-1.0.1       | 8 KB      | : 100% 1.0/1 [00:00<00:00,  3.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 154 KB    | :  10% 0.10369554623072005/1 [00:00<00:02,  2.69s/it]
#
#
#
# heapdict-1.0.1       | 8 KB      | : 100% 1.0/1 [00:00<00:00,  3.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# locket-1.0.0         | 11 KB     | : 100% 1.0/1 [00:00<00:00,  7.96it/s]
#
#
#
#
# itsdangerous-2.0.1   | 18 KB     | : 100% 1.0/1 [00:00<00:00,  7.59it/s]
#
# pcre-8.45            | 207 KB    | : 100% 1.0/1 [00:00<00:00,  1.68it/s]
#
# pcre-8.45            | 207 KB    | : 100% 1.0/1 [00:00<00:00,  1.68it/s]
#
#
# fontconfig-2.14.1    | 281 KB    | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
#
#
# fontconfig-2.14.1    | 281 KB    | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
#
#
#
#
#
# pkgutil-resolve-name | 9 KB      | : 100% 1.0/1 [00:00<00:00,  6.60it/s]
#
#
#
#
#
#
# nbformat-5.7.0       | 133 KB    | : 100% 1.0/1 [00:01<00:00,  1.00s/it]
#
#
#
#
#
#
# nbformat-5.7.0       | 133 KB    | : 100% 1.0/1 [00:01<00:00,  1.00s/it]
#
#
#
#
#
#
#
# mkl_fft-1.3.1        | 180 KB    | : 100% 1.0/1 [00:01<00:00,  1.10s/it]
#
#
#
#
#
#
#
# mkl_fft-1.3.1        | 180 KB    | : 100% 1.0/1 [00:01<00:00,  1.10s/it]
#
#
#
#
#
#
#
#
#
#
# sortedcontainers-2.4 | 26 KB     | : 100% 1.0/1 [00:01<00:00,  1.45s/it]
#
#
#
#
#
#
#
#
#
#
# sortedcontainers-2.4 | 26 KB     | : 100% 1.0/1 [00:01<00:00,  1.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# zipp-3.11.0          | 19 KB     | : 100% 1.0/1 [00:01<00:00,  4.08it/s]
#
#
#
#
#
#
#
#
#
#
#
# click-8.0.4          | 151 KB    | : 100% 1.0/1 [00:01<00:00,  1.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# click-8.0.4          | 151 KB    | : 100% 1.0/1 [00:01<00:00,  1.40s/it]
#
#
#
#
#
#
#
#
#
# tenacity-8.0.1       | 34 KB     | : 100% 1.0/1 [00:01<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
#
# tenacity-8.0.1       | 34 KB     | : 100% 1.0/1 [00:01<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# flit-core-3.6.0      | 42 KB     | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# flit-core-3.6.0      | 42 KB     | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 59 KB     | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 59 KB     | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libedit-3.1.20221030 | 181 KB    | : 100% 1.0/1 [00:01<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libedit-3.1.20221030 | 181 KB    | : 100% 1.0/1 [00:01<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.2     | 308 KB    | : 100% 1.0/1 [00:01<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.2     | 308 KB    | : 100% 1.0/1 [00:01<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
# krb5-1.19.4          | 1.3 MB    | : 100% 1.0/1 [00:01<00:00,  3.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 154 KB    | : 100% 1.0/1 [00:01<00:00,  1.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 154 KB    | : 100% 1.0/1 [00:01<00:00,  1.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# !conda --version
# !python --version
# Out:
# conda 23.1.0
# Python 3.8.15

# %%
# !conda install -c conda-forge fmpy --yes # Install the key package
# Out:
# done
# -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::typing-extensions==4.4.0=hd8ed1ab_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - fmpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     typing-extensions-4.4.0    |   py38h06a4308_0           8 KB
#     ------------------------------------------------------------
#                                            Total:           8 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-ha878542_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   conda              pkgs/main::conda-23.1.0-py38h06a4308_0 --> conda-forge::conda-23.1.0-py38h578d9bd_0
#   typing-extensions  conda-forge/noarch::typing-extensions~ --> pkgs/main/linux-64::typing-extensions-4.4.0-py38h06a4308_0
#
#
#
# Downloading and Extracting Packages
#
# done
# done
# done

# %%
# !conda install matplotlib --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-h06a4308_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/linux-64::certifi-2022.12.7-py38h06a4308_0
#   conda              conda-forge::conda-23.1.0-py38h578d9b~ --> pkgs/main::conda-23.1.0-py38h06a4308_0
#
#
#
# Downloading and Extracting Packages
#
# done
# done
# done

# %% [markdown]
# Now specific installation and the run simulations. Start with connecting to Github. Then upload the four files:
#
# * FMU - BPL_TEST2_Batch_linux_om_me.fmu
# * Setup-file - BPL_TEST2_Batch_explore.py

# %%
# !conda install scipy --yes
# Out:
# done
# done
#
# # All requested packages already installed.

# %%
# !conda install xlrd --yes
# Out:
# done
# done
#
# # All requested packages already installed.

# %%
# !conda install openpyxl --yes
# Out:
# done
# done
#
# # All requested packages already installed.

# %%
# %%bash
# git clone https://github.com/janpeter19/BPL_TEST2_Batch_calibration
# Out:
# Cloning into 'BPL_TEST2_Batch_calibration'...

# %%
# %cd BPL_TEST2_Batch_calibration
# Out:
# /tmp/tmpgbkwp8a8/binaries/linux64/BPL_TEST2_Batch_calibration

# %% [markdown]
# # BPL_TEST2_Batch_calibration - demo
# Author: Jan Peter Axelsson
#
# This notebook shows the possibilities for calibration of the model BPL_TEST2_Batch using scipy.optimize.minimize() routine. There are several different methods to choose between. In this notebook we work with simulated data.
#
# The text-book model of batch cultivation we simulate is the following where $S$ is substrate, $X$ is cell concentration, and $V$ is volume of the broth
#
# $$
# \eqalign{
# {d(VS) \over dt} =& -q_S(S) \cdot VX \cr
# {d(VX) \over dt} =& \mu(S) \cdot VX }
# $$
#
# and where specific cell growth rate $\mu$ and substrate uptake rate $q_S$ are
#
# $$
# \mu(S) = Y \cdot q_S(S)
# $$
#
# $$
# q_S(S) = q_S^{max} {S \over K_s + S}
# $$
#
# where $Y$ is the yield, $q_S^{max}$ is the maximal specific substrate uptake rate and $K_s$ is the corresponding saturation constant.
#
# The parameter estimation is done with optimization methods that only require evaluation of the missmatch between simulation with given parameters and data. At start the allowed range for each parameter is given. The method used for optimization is SLSQP but can easily be changed [1].
#
# In the near future the FMU may provide first derivative gradient informaion, that will make it possible to choose corresponding method of minimize() for improved performance. This possibility is related to the upgrade to the FMI-standard ver 3.0 for the Modelica compiler.
#
# The Python package PyFMI [2] that is the base for FMU-explore has a simplified built-in
# functionality for parameter estimation that also use scipy.optimize.minimize(). However, there is estimatation functionaly but the purpose seems to only address smaller examples. There is for instance no support to handle models that takes sub-models from libraries and necesssary changes of default parameters not to be estimated. Therefore we here define a Python function evaluate() that facilitate the formulation of the parameter estimation and also bring flexibility to choice of optimization method, default Nelder-Mead.

# %%
run -i BPL_TEST2_Batch_fmpy_explore.py
# Out:
# Linux - run FMU pre-compiled JModelica 2.4
#
# Model for bioreactor has been setup. Key commands:
#  - par()       - change of parameters and initial values
#  - init()      - change initial values only
#  - simu()      - simulate and plot
#  - newplot()   - make a new plot
#  - show()      - show plot from previous simulation
#  - disp()      - display parameters and initial values from the last simulation
#  - describe()  - describe culture, broth, parameters, variables with values / units
#
# Note that both disp() and describe() takes values from the last simulation
#
# Brief information about a command by help(), eg help(simu)
# Key system information is listed with the command system_info()

# %%
# Adjust the size of diagrams
plt.rcParams['figure.figsize'] = [15/2.54, 12/2.54]

# %% [markdown]
# ## 1 Generate data later used for parameter estimation

# %%
import pandas as pd

# %%
# Data generated
simulationTime = 6.0
par(Y=0.50, qSmax=1.00, Ks=0.1)
init(V_0=1.0, VS_0=10, VX_0=1.0)
newplot(plotType='Demo_2')
simu(simulationTime, output_interval=simulationTime/12)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/fmpy/fmi1.py in __init__(self, guid, modelIdentifier, unzipDirectory, instanceName, libraryPath, fmiCallLogger, requireFunctions)
#     162         try:
# --> 163             self.dll = cdll.LoadLibrary(libraryPath)
#     164         except Exception as e:
#
# /usr/lib/python3.9/ctypes/__init__.py in LoadLibrary(self, name)
#     451     def LoadLibrary(self, name):
# --> 452         return self._dlltype(name)
#     453
#
# /usr/lib/python3.9/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373         if handle is None:
# --> 374             self._handle = _dlopen(self._name, mode)
#     375         else:
#
# OSError: libgfortran.so.4: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# BPL_TEST2_Batch_fmpy_explore.py in <module>
#       4 init(V_0=1.0, VS_0=10, VX_0=1.0)
#       5 newplot(plotType='Demo_2')
# ----> 6 simu(simulationTime, output_interval=simulationTime/12)
#
# BPL_TEST2_Batch_fmpy_explore.py in simu(simulationTime, diagrams, output_interval)
#     428        return output
#     429
# --> 430    sim_res = simulate_fmu(
#     431       filename = fmu_model,
#     432       validate = False,
#
# /usr/local/lib/python3.8/site-packages/fmpy/simulation.py in simulate_fmu(filename, validate, start_time, stop_time, solver, step_size, relative_tolerance, output_interval, record_events, fmi_type, start_values, apply_default_start_values, input, output, timeout, debug_logging, visible, logger, fmi_call_logger, step_finished, model_description, fmu_instance, set_input_derivatives, remote_platform, early_return_allowed, use_event_mode, initialize, terminate, fmu_state)
#     736
#     737     if fmu_instance is None:
# --> 738         fmu = instantiate_fmu(unzipdir, model_description, fmi_type, visible, debug_logging, logger, fmi_call_logger, None, early_return_allowed, use_event_mode, None, validate)
#     739     else:
#     740         fmu = fmu_instance
#
# /usr/local/lib/python3.8/site-packages/fmpy/simulation.py in instantiate_fmu(unzipdir, model_description, fmi_type, visible, debug_logging, logger, fmi_call_logger, library_path, early_return_allowed, event_mode_used, intermediate_update, require_functions)
#     818             fmu.instantiate(functions=callbacks, loggingOn=debug_logging)
#     819         elif is_fmi2:
# --> 820             fmu = FMU2Slave(**fmu_args)
#     821             fmu.instantiate(visible=visible, callbacks=callbacks, loggingOn=debug_logging)
#     822         else:
#
# /usr/local/lib/python3.8/site-packages/fmpy/fmi2.py in __init__(self, instanceName, **kwargs)
#     522         kwargs['instanceName'] = instanceName
#     523
# --> 524         super(FMU2Slave, self).__init__(**kwargs)
#     525
#     526         # Simulating the slave
#
# /usr/local/lib/python3.8/site-packages/fmpy/fmi2.py in __init__(self, **kwargs)
#      83     def __init__(self, **kwargs):
#      84
# ---> 85         super(_FMU2, self).__init__(**kwargs)
#      86
#      87         # Inquire version numbers of header files and setting logging status
#
# /usr/local/lib/python3.8/site-packages/fmpy/fmi1.py in __init__(self, guid, modelIdentifier, unzipDirectory, instanceName, libraryPath, fmiCallLogger, requireFunctions)
#     163             self.dll = cdll.LoadLibrary(libraryPath)
#     164         except Exception as e:
# --> 165             raise Exception("Failed to load shared library %s. %s" % (libraryPath, e))
#     166
#     167         # change back to the working directory
#
# Exception: Failed to load shared library /tmp/tmp_exg5p4_/binaries/linux64/BPL_TEST2_Batch.so. libgfortran.so.4: cannot open shared object file: No such file or directory

# %%
# Store data in a DataFrame for later use
data = pd.DataFrame(data={'time':sim_res['time'], 'X':sim_res['bioreactor.c[1]'], 'S':sim_res['bioreactor.c[2]']})
data

# %% [markdown]
# ## 2 Simulation with initial guess of parameters compared with data
#
# Here we define the parameters that should be estimated and specify allowed ranges.
# Nominal parameters are chosen as the mid-point of the allowed parameter range.
#
# Simulation with these nominal parameter set and compare with data give an idea of who well the model fit data.

# %%
# Parameters to be estimated using parDict names and their bounds
parEstim = ['Y', 'qSmax', 'Ks']
parBounds = [(0.4, 0.8), (0.7, 1.3), (0.05, 0.20)]
parEstim_0 = [np.mean(parBounds[k]) for k in range(len(parBounds))]

# %%
# Simulation with nominal parameters
newplot(plotType='Demo_1')
par(Y=parEstim_0[0], qSmax=parEstim_0[1], Ks=parEstim_0[2])
simu(simulationTime)

# Show data
ax1.plot(data['time'], data['S'],'b*')
ax2.plot(data['time'], data['X'],'r*')
plt.show()

# %%
# Simulation over the parameter ranges given
newplot(plotType='Demo_1')
for Y_value in parBounds [0]:
    for qSmax_value in parBounds[1]:
        for Ks_value in parBounds[2]:
            par(Y=Y_value, qSmax=qSmax_value, Ks=Ks_value)
            simu(simulationTime)
            
# Show data
ax1.plot(data['time'], data['S'],'b*')
ax2.plot(data['time'], data['X'],'r*')
plt.show()

# %% [markdown]
# Simulation over the diferent parameter combinations of the parameter bounds shows that data is "covered" and we have good hope to find a parameter combination that fits data well.

# %% [markdown]
# ## 3 Parameter estimation
#
# Here we use the scipy.optimize.minimize() procedure which contain a family of different methods [1].
# The default method is Nelder-Mead and is robust for fitting a model to data. Further we have chosen to work with bounds for the parameters to be estimated and the initial guess is chosen as the middle point in parameter space.

# %%
# Optimization routine import
import scipy.optimize

# %%
# Parameters to be estimated using parDict names and their bounds
extra_args = (parEstim, data, fmu_model, simulationTime)

# %%
# Modified evaluation function tailored for Python optimization algorithms
def evaluate(x, parEstim, data=data, fmu_model=fmu_model, simulationTime=simulationTime):
    """The parameter list is tailored for scipy optimization algorithms interface, 
       where the first parameter x is an array with parameters that are tuned 
       and evalauted and parEstim is a list of the names of these parameters.
       The code can be made 20-30% faster, but loner, using pyfmi-commands directly."""
    
    # Update parameters and simulate
    for i, p in enumerate(parEstim): par(**{p:x[i]})
    simu(simulationTime, options=opts_fast)
 
    # Calculate loss function V
    V={}
    V['X'] = np.linalg.norm(data['X'] - np.interp(data['time'], sim_res['time'], sim_res['bioreactor.c[1]']))
    V['S'] = np.linalg.norm(data['S'] - np.interp(data['time'], sim_res['time'], sim_res['bioreactor.c[2]']))
  
    return V['X'] + V['S']

# %%
import time

# %%
# Run minimize()
start_time = time.time()
result = scipy.optimize.minimize(evaluate, x0=parEstim_0, args=extra_args, 
                                 method='Nelder-Mead', bounds=parBounds, options={"disp":True})
print('CPU-time =', time.time()-start_time)

# %%
result

# %% [markdown]
# The estimated parameters result.x are very close to the original values and no surprise.

# %% [markdown]
# ## 4 Simulation with estimated parameters compared with data

# %%
newplot(plotType='Demo_1')
par(Y=result.x[0], qSmax=result.x[1], Ks=result.x[2])
simu(simulationTime)

# Show data
ax1.plot(data['time'], data['S'],'b*')
ax2.plot(data['time'], data['X'],'r*')
plt.show()

# %%
# The estimated parameters are
for i in range(len(parEstim)): print(parEstim[i],':', result.x[i])

# %% [markdown]
# ## 5 Analysis of the loss function
#
# The problem is small and analysis of the loss function brings some insight. From the diagram above showing parameter sweep over combinations min- and max-parameters we see that the parameter $K_s$ has little influence. Let use set that a fixed value and then plot the loss function in the parameters $Y$ and $qSmax$.  We do this by go through all the parametera combinations and evaluate each of them.

# %%
# Sweep through Y and qSmax variation and store the value of the loss-function for each
nY = 20
nqSmax = 20
V = np.zeros((nY, nqSmax))
             
Y = np.linspace(parBounds[0][0],parBounds[0][1],nY)
qSmax = np.linspace(parBounds[1][0],parBounds[1][1],nqSmax)

for j in range(nY):
    for k in range(nqSmax):
        V[k,j] = evaluate([Y[j], qSmax[k], 0.1], parEstim)

# Contour plot
plt.figure()
plt.clf
plt.subplot(1,1,1)
plt.contourf(Y, qSmax, V, 20, cmap='RdGy')
plt.plot(result.x[0], result.x[1],'k+')
plt.colorbar()
plt.ylabel('qSmax')
plt.xlabel('Y')
plt.show()

# %% [markdown]
# We see the following in the contour diagram of the loss function simplified:
# * The minima is unique in the range of parmaters we study. This is good news.
# * The contour plot is ellipsoid and rather narrow. The more narrow the ellipsoid the more difficult and more time it takes to converge to the minima.
# * The direction of the ellipsoid axis indicate the correlation you may get between the two parameters during the minimization process.
#
# Note that the form of the contour plot change with the parameters (and initial values) of the actual proces.
# You can see the impact by changing the parameters in "cell # 4" where data is generated and then just choose to run that cell and the cells below. No need to restart the notebook.

# %% [markdown]
# ## 6 Summary
#
# A choice was made to work with allowed ranges of parameters to be estimated and a start value was defined as the center point in this parameter space. There are only three methods available in optimize.minimize() that can handle bounds on parameters.
#
# An evaluate() function was created that define how the difference beween simulation and data is measured. The function is rather transparent and easy to modify and you may want to change weight on the loss in S and X, for instance. Here they have so far equal weight.
#
# The FMU-explore workspace dictionaries partDict[] and parLocation[] are useful also here and simplify the code for the evaluation() function. But we also use the detailed PyFMI-functions to administrate and set parameters of the actual simulation.
#
# The call optimize.minimize() has several parameters and can easily be modified, for instance change of method. For fitting a model to data Nelder-Mead is ao a robust and good choice, but can be somewhat slow.
#
# The estimated parameters were close to perfect!
#
# The contour plot of the simplified loss function shows that the minima is unique and should
# not be difficult too difficut to obtain. More narrow elliptical contour plots would indicate difficulties. Multiple local minima would also be a problem.

# %% [markdown]
# ## 7 References
#
# [1] Scipy Reference guide on optimize.minimize()
# [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html?highlight=minimize)
#
# [2] Andersson, C., Åkesson, J., Fuhrer C. : "PyFMI: A Python package for simulation of coupled dynamic models with the functional mock-up interface", Centre for Mathematical Sciences, Lund University, Report LUTFNA-5008-2016, 2016.

# %% [markdown]
# ## Appendix

# %%
describe('parts')

# %%
describe('MSL')

# %%
system_info()
# Out:
# System information
#  -OS: Linux
#  -Python: 3.9.16
#  -Scipy: not installed in the notebook
#  -FMPy: 0.3.15
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# BPL_TEST2_Batch_fmpy_explore.py in <module>
# ----> 1 system_info()
#
# BPL_TEST2_Batch_fmpy_explore.py in system_info()
#     551        print(' -Scipy: not installed in the notebook')
#     552    print(' -FMPy:', version('fmpy'))
# --> 553    print(' -FMU by:', read_model_description(fmu_model).generationTool)
#     554    print(' -FMI:', read_model_description(fmu_model).fmiVersion)
#     555    if model_description.modelExchange is None:
#
# /usr/local/lib/python3.8/site-packages/fmpy/model_description.py in read_model_description(filename, validate, validate_variable_names, validate_model_structure)
#     434         tree = etree.parse(filename)
#     435     else:  # FMU as path or file like object
# --> 436         with zipfile.ZipFile(filename, 'r') as zf:
#     437             xml = zf.open('modelDescription.xml')
#     438             tree = etree.parse(xml)
#
# /usr/lib/python3.9/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1246             while True:
#    1247                 try:
# -> 1248                     self.fp = io.open(file, filemode)
#    1249                 except OSError:
#    1250                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'BPL_TEST2_Batch_linux_jm_cs.fmu'

# %%
fmu_model
# Out:
# 'BPL_TEST2_Batch_linux_jm_cs.fmu'
